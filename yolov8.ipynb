# %%
# !nvidia-smi
# Out:
# Sat Jul 13 10:03:10 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics==8.0.196
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 6.9 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.1/78.2 GB disk)
#
# OS                  Linux-6.1.85+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.67 GB
# CPU                 Intel Xeon 2.00GHz
# CUDA                12.1
#
# matplotlib          ✅ 3.7.1>=3.3.0
# numpy               ✅ 1.25.2>=1.22.2
# opencv-python       ✅ 4.8.0.76>=4.6.0
# pillow              ✅ 9.4.0>=7.1.2
# pyyaml              ✅ 6.0.1>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.11.4>=1.4.1
# torch               ✅ 2.3.0+cu121>=1.8.0
# torchvision         ✅ 0.18.0+cu121>=0.9.0
# tqdm                ✅ 4.66.4>=4.64.0
# pandas              ✅ 2.0.3>=1.1.4
# seaborn             ✅ 0.13.1>=0.11.0
# psutil              ✅ 5.9.5
# py-cpuinfo          ✅ 9.0.0
# thop                ✅ 0.1.1-2209072238>=0.1.1

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xuSwiUvux71WDJ1Gsp32")
project = rf.workspace("2024-csi-microg-next").project("see-lion")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolov8m.pt data={dataset.location}/data.yaml epochs=20 imgsz=640
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 274MB/s]
# New https://pypi.org/project/ultralytics/8.2.55 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842076 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/SEE-LION-1/valid/labels.cache... 79 images, 0 backgrounds, 0 corrupt: 100% 79/79 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:04<00:00,  1.11it/s]
#                    all         79         83      0.805      0.733      0.778       0.63
# Mannequin_wearing_orange-colored_life_preserver_unit_(LPU)         79          5      0.749        0.2      0.368       0.18
# Multi-person_life_raft         79         72      0.977          1      0.995       0.96
# Orion_capsule_mockup_(WEST)_located_on_far_end_of_pool         79          6      0.688          1      0.972       0.75
# Speed: 3.7ms preprocess, 26.5ms inference, 0.0ms loss, 9.2ms postprocess per image
# Results saved to runs/detect/val
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.5 source={dataset.location}/IMG_7686.mov
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842076 parameters, 0 gradients, 78.7 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# video 1/1 (1/826) /content/SEE-LION-1/IMG_7686.mov: 384x640 1 Multi-person_life_raft, 91.3ms
# video 1/1 (2/826) /content/SEE-LION-1/IMG_7686.mov: 384x640 1 Multi-person_life_raft, 25.2ms
# video 1/1 (3/826) /content/SEE-LION-1/IMG_7686.mov: 384x640 1 Multi-person_life_raft, 25.3ms
# video 1/1 (4/826) /content/SEE-LION-1/IMG_7686.mov: 384x640 1 Multi-person_life_raft, 25.2ms
# video 1/1 (5/826) /content/SEE-LION-1/IMG_7686.mov: 384x640 1 Multi-person_life_raft, 25.2ms
# video 1/1 (6/826) /content/SEE-LION-1/IMG_7686.mov: 384x640 1 Multi-person_life_raft, 25.1ms
# video 1/1 (7/826) /content/SEE-LION-1/IMG_7686.mov: 384x640 1 Multi-person_life_raft, 25.2ms
# video 1/1 (8/826) /content/SEE-LION-1/IMG_7686.mov: 384x640 1 Multi-person_life_raft, 25.2ms
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# Out:
# /content

# %%
# !zip -r SEE-LION-1.zip /content/SEE-LION-1
# Out:
#   adding: content/SEE-LION-1/ (stored 0%)
#   adding: content/SEE-LION-1/data.yaml (deflated 41%)
#   adding: content/SEE-LION-1/README.dataset.txt (deflated 16%)
#   adding: content/SEE-LION-1/IMG_7548.mov (deflated 0%)
#   adding: content/SEE-LION-1/train/ (stored 0%)
#   adding: content/SEE-LION-1/train/labels.cache (deflated 67%)
#   adding: content/SEE-LION-1/train/labels/ (stored 0%)
#   adding: content/SEE-LION-1/train/labels/IMG_7773_jpeg.rf.2ff7c552b3f341575abbd3400c377dbf.txt (deflated 19%)
#   adding: content/SEE-LION-1/train/labels/IMG_7687_jpeg.rf.f472d55c8e9f058b6b7170fcf45b60de.txt (deflated 16%)
#   adding: content/SEE-LION-1/train/labels/IMG_7762_jpeg.rf.b9507a56b21c86124d544e217551ea38.txt (deflated 16%)
#   adding: content/SEE-LION-1/train/labels/IMG_7525_jpeg.rf.53658e445f68a6826544873f739d02a1.txt (deflated 16%)
#   adding: content/SEE-LION-1/train/labels/IMG_7699_jpeg.rf.414d6fb3d5fea402891fef3f394999d4.txt (deflated 18%)
# ...

# %%
from google.colab import files
files.download('/content/SEE-LION-1.zip')

# %%
# !zip -r runs.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/predict3/ (stored 0%)
#   adding: content/runs/detect/predict3/IMG_7686.avi (deflated 1%)
#   adding: content/runs/detect/predict/ (stored 0%)
#   adding: content/runs/detect/predict/IMG_7548.avi (deflated 2%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/val_batch0_labels.jpg (deflated 6%)
#   adding: content/runs/detect/train/results.png (deflated 6%)
#   adding: content/runs/detect/train/val_batch1_pred.jpg (deflated 5%)
#   adding: content/runs/detect/train/PR_curve.png (deflated 19%)
#   adding: content/runs/detect/train/R_curve.png (deflated 15%)
#   adding: content/runs/detect/train/confusion_matrix.png (deflated 23%)
#   adding: content/runs/detect/train/confusion_matrix_normalized.png (deflated 22%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
# ...

# %%
from google.colab import files
files.download('/content/runs.zip')
